# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('telecom_churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['AccountWeeks'], row['CustServCalls'])

# Add attributes to the Graph object
nx.set_node_attributes(G, df.set_index('AccountWeeks')['Churn'], 'Churn')
nx.set_node_attributes(G, df.set_index('AccountWeeks')['MonthlyCharge'], 'MonthlyCharge')
nx.set_node_attributes(G, df.set_index('AccountWeeks')['RoamMins'], 'RoamMins')

# Visualize the network graph
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('telecom_churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['AccountWeeks'], row['CustServCalls'])

# Add attributes to the Graph object
nx.set_node_attributes(G, df.set_index('AccountWeeks')['Churn'], 'Churn')
#nx.set_node_attributes(G, df.set_index('AccountWeeks')['MonthlyCharge'], 'MonthlyCharge')
nx.set_node_attributes(G, df.set_index('AccountWeeks')['RoamMins'], 'RoamMins')

# Visualize the network graph
pos = nx.spring_layout(G, k=0.9)
nx.draw(G, pos, with_labels=True, node_size=90, font_size=8, width=0.1)
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('telecom_churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['AccountWeeks'], row['CustServCalls'])

# Add attributes to the Graph object
nx.set_node_attributes(G, df.set_index('AccountWeeks')['Churn'], 'Churn')

# Visualize the network graph
pos = nx.spring_layout(G, k=0.9)
nx.draw(G, pos, with_labels=True, node_size=90, width=0.1)
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('telecom_churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['AccountWeeks'], row['CustServCalls'])

# Add attributes to the Graph object
nx.set_node_attributes(G, df.set_index('AccountWeeks')['MonthlyCharge'], 'MonthlyCharge')

# Visualize the network graph
pos = nx.spring_layout(G, k=0.9)
nx.draw(G, pos, with_labels=True, node_size=90, width=0.1)
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('telecom_churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['AccountWeeks'], row['CustServCalls'])

# Add attributes to the Graph object
nx.set_node_attributes(G, df.set_index('AccountWeeks')['RoamMins'], 'RoamMins')

# Visualize the network graph
pos = nx.spring_layout(G, k=0.9)
nx.draw(G, pos, with_labels=True, node_size=90, width=0.1)
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('Teleco-Customer-Churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['tenure'], row['PhoneService'])

# Add attributes to the Graph object
nx.set_node_attributes(G, df.set_index('tenure')['Churn'], 'Churn')
nx.set_node_attributes(G, df.set_index('tenure')['Contract'], 'MonthlyCharge')
nx.set_node_attributes(G, df.set_index('tenure')['TotalCharges'], 'TotalCharges')

# Visualize the network graph
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('Teleco-Customer-Churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['tenure'], row['PhoneService'])

# Add attributes to the Graph object
#nx.set_node_attributes(G, df.set_index('tenure')['Churn'], 'Churn')
#nx.set_node_attributes(G, df.set_index('tenure')['Contract'], 'MonthlyCharge')
#nx.set_node_attributes(G, df.set_index('tenure')['TotalCharges'], 'TotalCharges')

# Visualize the network graph
pos = nx.spring_layout(G, k=0.95)
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)
nx.draw(G, pos, node_size=90, font_size=9, width=1.8)
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Load telecom data set into a pandas DataFrame
df = pd.read_csv('Teleco-Customer-Churn.csv')

# Create networkx Graph object
G = nx.Graph()

# Add nodes and edges to the Graph object
for index, row in df.iterrows():
    G.add_edge(row['tenure'], row['PhoneService'])

# Add attributes to the Graph object
nx.set_node_attributes(G, df.set_index('tenure')['Churn'], 'Churn')
nx.set_node_attributes(G, df.set_index('tenure')['Contract'], 'MonthlyCharge')
nx.set_node_attributes(G, df.set_index('tenure')['TotalCharges'], 'TotalCharges')

# Visualize the network graph
pos = nx.spring_layout(G, k=9.99)
pos = {k:(v[0],v[1]+10.85) for k,v in pos.items()}
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)
plt.show()
